# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
d1=pd.read_csv('happiness_score.csv')
d1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
order=[0,1,4,5,6,7,8,9,10,11,2,3]
d1=d1[[d1.columns[i]for i in order]]

# %%
d1.head()
# Out:
#        Country          Region  Standard Error  Economy (GDP per Capita)  \
# 0  Switzerland  Western Europe         0.03411                   1.39651
# 1      Iceland  Western Europe         0.04884                   1.30232
# 2      Denmark  Western Europe         0.03328                   1.32548
# 3       Norway  Western Europe         0.03880                   1.45900
# 4       Canada   North America         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Happiness Rank  Happiness Score
# 0     0.29678            2.51738               1            7.587
# 1     0.43630            2.70201               2            7.561
# 2     0.34139            2.49204               3            7.527
# 3     0.34699            2.46531               4            7.522
# 4     0.45811            2.45176               5            7.427

# %%
d1.shape
# Out:
# (158, 12)

# %%
d1.columns
# Out:
# Index(['Country', 'Region', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual',
#        'Happiness Rank', 'Happiness Score'],
#       dtype='object')

# %%
d1.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# Happiness Rank                   0
# Happiness Score                  0
# dtype: int64

# %%
#there are no null/missing values

# %%
sns.heatmap(d1.isnull())

# %%
d1.describe()
# Out:
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual  Happiness Rank  Happiness Score
# count  158.000000         158.000000      158.000000       158.000000
# mean     0.237296           2.098977       79.493671         5.375734
# std      0.126685           0.553550       45.754363         1.145010
# min      0.000000           0.328580        1.000000         2.839000
# 25%      0.150553           1.759410       40.250000         4.526000
# 50%      0.216130           2.095415       79.500000         5.232500
# 75%      0.309883           2.462415      118.750000         6.243750
# max      0.795880           3.602140      158.000000         7.587000

# %%
#there are 158 rows in the dataset
#the large difference between 75% and max shows the presence of outliers

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
#  10  Happiness Rank                 158 non-null    int64
#  11  Happiness Score                158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=["Country","Region"]
for val in list1:
    d1[val]=le.fit_transform(d1[val].astype(str))

# %%
d1.head()
# Out:
#    Country  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0      135       9         0.03411                   1.39651  1.34951
# 1       58       9         0.04884                   1.30232  1.40223
# 2       37       9         0.03328                   1.32548  1.36058
# 3      105       9         0.03880                   1.45900  1.33095
# 4       24       5         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Happiness Rank  Happiness Score
# 0     0.29678            2.51738               1            7.587
# 1     0.43630            2.70201               2            7.561
# 2     0.34139            2.49204               3            7.527
# 3     0.34699            2.46531               4            7.522
# 4     0.45811            2.45176               5            7.427

# %%
d1cor=d1.corr()
sns.heatmap(d1cor)

# %%
plt.figure(figsize=(10,4))
sns.heatmap(d1cor,cmap='Blues',annot=True)

# %%
#Happiness score depends strongly on economy,family and health.
#it also has a good correlation with freedom,trust and generosity
#it is poorly correlated with country
#it is negatively related with region and standard error

# %%
d1.plot(kind='bar')
plt.title('happiness score vs health')
plt.xlabel('Happiness Score')
plt.ylabel('Health (Life Expectancy)')
plt.show()

# %%
#here we can see that happiness score increases with life expectancy

# %%
d1.plot(kind='bar')
plt.title('happiness score vs Freedom')
plt.xlabel('Happiness Score')
plt.ylabel('Freedom')
plt.show()

# %%
#freedom and happiness have a positive correlation

# %%
collist=d1.columns.values
ncol=10
nrows=7

# %%
plt.figure(figsize=(ncol,2*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(d1[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
#box plot shows how the data is spread ,standard error,family trust and dystopia have outliers present

# %%
d1.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# dtype: float64

# %%
#standard error,family,trust,and generosity are highly skewed datas

# %%
for col in d1.columns:
    if d1.skew().loc[col]>0.55:
        d1[col]=np.log1p(d1[col])
d1.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Standard Error                   1.890608
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.180922
# Generosity                       0.650767
# Dystopia Residual               -0.238911
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# dtype: float64

# %%
plt.figure(figsize=(20,20))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(d1[collist[i]])

# %%
#standard error,family and trust are little skewed

# %%
from scipy.stats import zscore
z=np.abs(zscore(d1))
z
# Out:
# array([[1.23877001, 1.30025593, 0.81564478, ..., 0.75825809, 1.72099989,
#         1.93736005],
#        [0.44946522, 1.30025593, 0.06483715, ..., 1.09285682, 1.69907456,
#         1.91458063],
#        [0.90989302, 1.30025593, 0.86563039, ..., 0.71233526, 1.67714922,
#         1.88479215],
#        ...,
#        [1.26069514, 0.37544095, 0.14254239, ..., 3.20843049, 1.67742676,
#         2.0761992 ],
#        [1.26069514, 0.96511655, 2.26549801, ..., 0.48198451, 1.69935209,
#         2.1646885 ],
#        [1.37032081, 0.96511655, 1.14923184, ..., 0.96361241, 1.72127743,
#         2.22251319]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
d1_new=d1[(z<3).all(axis=1)]
print(d1.shape)
print(d1_new.shape)
# Out:
# (158, 12)
# (150, 12)

# %%
#8 rows are deleted due to outliers

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
x=d1_new.iloc[:,:-1]
x
# Out:
#      Country  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0        135       9        0.033541                   1.39651  1.34951
# 1         58       9        0.047685                   1.30232  1.40223
# 2         37       9        0.032738                   1.32548  1.36058
# 3        105       9        0.038066                   1.45900  1.33095
# 4         24       5        0.034913                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 150       66       8        0.050132                   0.46534  0.77115
# 151       20       8        0.042331                   0.25812  0.85188
# 152        0       7        0.030374                   0.31982  0.30285
# 154       13       8        0.035908                   0.28665  0.35386
# 156       21       8        0.083035                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                       0.350502
# 1                     0.94784  0.62877                       0.132299
# 2                     0.87464  0.64938                       0.394451
# 3                     0.88521  0.66973                       0.311176
# 4                     0.90563  0.63297                       0.284856
# ..                        ...      ...                            ...
# 150                   0.15185  0.46866                       0.164853
# 151                   0.27125  0.39493                       0.120730
# 152                   0.30335  0.23414                       0.092752
# 154                   0.31910  0.48450                       0.077054
# 156                   0.22396  0.11850                       0.095874
#
#      Generosity  Dystopia Residual  Happiness Rank
# 0      0.259884            2.51738               1
# 1      0.362070            2.70201               2
# 2      0.293706            2.49204               3
# 3      0.297872            2.46531               4
# 4      0.377141            2.45176               5
# ..          ...                ...             ...
# 150    0.183696            1.41723             151
# 151    0.196775            1.46494             152
# 152    0.311228            1.95210             153
# 154    0.167715            1.63328             155
# 156    0.180044            1.83302             157
#
# [150 rows x 11 columns]

# %%
y=d1_new.iloc[:,-1]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 150, dtype: float64

# %%
max_r_score=0
for r_state in range(41,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 86 is 0.9999652954166569

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.2640521 ,  1.30301762, -0.87885739, ...,  0.58711486,
#          0.76366883, -1.70523445],
#        [-0.42339609,  1.30301762,  0.18553243, ...,  1.664233  ,
#          1.11591405, -1.68288147],
#        [-0.88360924,  1.30301762, -0.93928359, ...,  0.94362541,
#          0.71532407, -1.66052849],
#        ...,
#        [-1.69446097,  0.63934142, -1.11720354, ...,  1.12831302,
#         -0.31479717,  1.69241874],
#        [-1.40956712,  0.97117952, -0.70077336, ..., -0.38441416,
#         -0.92305596,  1.7371247 ],
#        [-1.23424783,  0.97117952,  2.84584938, ..., -0.25446188,
#         -0.54198322,  1.78183066]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=86)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 1.11076977e-03, -4.05938380e-04, -1.21931624e-03,  3.93128075e-01,
#         2.48855834e-01,  2.44219953e-01,  1.48811489e-01,  1.15212055e-01,
#         1.20005904e-01,  5.21052182e-01, -3.92108786e-03])

# %%
lm.intercept_
# Out:
# 5.437870329309262

# %%
lm.score(x_train,y_train)
# Out:
# 0.9999242573426784

# %%
pred=lm.predict(x_test)
print('predicted o/p:',pred)
print('actual o/p',y_test)
# Out:
# predicted o/p: [6.47423324 4.57329441 6.49543724 5.76166588 7.56112203 4.19379945
#  5.83841066 4.03020294 4.24863993 5.78141573 7.26675632 5.12598614
#  3.89304478 6.27264533 5.36630996 3.93398003 5.85446884 4.21003905
#  7.27770469 3.66523679 6.90601028 3.59242922 6.41692284 4.51597743
#  5.47645784 4.97166206 6.33662926 5.08258614 4.51769502 5.28688383
#  4.84630523 6.12629223 5.88330457]
# actual o/p 32     6.477
# 116    4.565
# 30     6.505
# 62     5.754
# 1      7.561
# 134    4.194
# 56     5.828
# 136    4.033
# 132    4.252
# 60     5.770
# 8      7.286
# 86     5.123
# 142    3.896
# 39     6.269
# 74     5.360
# 140    3.931
# 54     5.848
# 133    4.218
# 9      7.284
# 148    3.667
# 19     6.901
# 151    3.587
# 34     6.411
# 120    4.514
# 71     5.474
# 93     4.971
# 35     6.329
# 89     5.073
# 121    4.512
# 76     5.286
# 102    4.839
# 41     6.130
# 52     5.878
# Name: Happiness Score, dtype: float64

# %%
print('error:')
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared error:',mean_squared_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# mean absolute error: 0.005417456404634266
# mean squared error: 4.427472450240901e-05
# root mean squared error: 0.006653925495706201

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.9999636306276686

# %%
from sklearn.model_selection import cross_val_score
lmscores=cross_val_score(lm,x,y,cv=5)
print(lmscores)
print(lmscores.mean(),lmscores.std())
# Out:
# [0.99802661 0.99794998 0.99731488 0.99648005 0.99955038]
# 0.9978643817165394 0.0010094117086458633

# %%
from sklearn .linear_model import Lasso,Ridge, ElasticNet
ls=Lasso(alpha=.001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9999022210107433

# %%
ls.coef_
# Out:
# array([ 2.80878657e-04,  0.00000000e+00, -1.25006788e-03,  3.77224428e-01,
#         2.39219076e-01,  2.33498385e-01,  1.42788796e-01,  1.11575125e-01,
#         1.15181438e-01,  4.99909601e-01, -4.75653385e-02])

# %%
lscores=cross_val_score(ls,x,y,cv=5)
print(lscores)
print(lscores.mean(),lscores.std())
# Out:
# [0.98310739 0.99630517 0.99746019 0.99717104 0.99870953]
# 0.9945506634046284 0.005773293633593237

# %%
rd=Ridge(alpha=.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9999242573281644

# %%
rd.coef_
# Out:
# array([ 1.11085559e-03, -4.04774525e-04, -1.21990964e-03,  3.93113628e-01,
#         2.48847415e-01,  2.44211283e-01,  1.48806204e-01,  1.15209094e-01,
#         1.20001777e-01,  5.21033912e-01, -3.95967690e-03])

# %%
rdscores=cross_val_score(rd,x,y,cv=5)
print(rdscores)
print(rdscores.mean(),rdscores.std())
# Out:
# [0.99802485 0.99794936 0.99731544 0.99648052 0.99955004]
# 0.997864041149532 0.0010090410646001599

# %%
enr=ElasticNet(alpha=.001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.9999074294901242
# array([ 7.34961892e-04,  2.63328290e-04, -1.52203521e-03,  3.78239730e-01,
#         2.40050872e-01,  2.34745778e-01,  1.43298438e-01,  1.12016262e-01,
#         1.15647020e-01,  5.01759226e-01, -4.40898006e-02])

# %%
enrscores=cross_val_score(enr,x,y,cv=5)
print(enrscores)
print(enrscores.mean(),enrscores.std())
# Out:
# [0.98904154 0.99655182 0.99750805 0.99683417 0.99877052]
# 0.9957412193763334 0.0034361482934957307

# %%
from sklearn.svm import SVR
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
svr=SVR(kernel='poly')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.9976421206827821
# 0.974648390180207
# 0.9869085321319447

# %%
svrscores=cross_val_score(svr,x,y,cv=5)
print(svrscores)
print(svrscores.mean(),svrscores.std())
# Out:
# [-12.88749504   0.31094674   0.79789833  -0.98865597  -6.18094278]
# -3.789649742790572 5.1806394638051305

# %%
#ridge regression method gives a better accuracy score than others.so we choose ridge regression method for this analysis

# %%
import joblib
joblib.dump(rd,'rd_happiness.pkl')
# Out:
# ['rd_happiness.pkl']
